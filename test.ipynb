# %%
from utils.io import readData,readLabel
import pandas as pd

pd.options.display.max_columns=None
pd.options.display.max_rows=100

train=readData("/Users/harmonialeo/Downloads/train.csv",",","Id")
X,y=readLabel(train,"SalePrice")
test=readData("/Users/harmonialeo/Downloads/test.csv",",","Id")
trainIds=X.index
testIds=test.index
data=X.append(test)
# Out:
# Get data with 1460 rows and 80 cols.
# Get features with 1460 rows and 79 cols and labels with 1460 rows.
# Get data with 1459 rows and 79 cols.

# %%
data
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# ...          ...      ...          ...      ...    ...   ...      ...
# 2915         160       RM         21.0     1936   Pave   NaN      Reg
# 2916         160       RM         21.0     1894   Pave   NaN      Reg
# 2917          20       RL        160.0    20000   Pave   NaN      Reg
# 2918          85       RL         62.0    10441   Pave   NaN      Reg
# 2919          60       RL         74.0     9627   Pave   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# ...

# %%
data.columns
# Out:
# Index(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street', 'Alley',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
# ...

# %%
import numpy as np

ttn = data.select_dtypes(include=[np.number])
cols=ttn.columns
cols
# Out:
# Index(['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
#        'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold'],
#       dtype='object')

# %%
ttn = data.select_dtypes(exclude=[np.number])
cols=ttn.columns
cols
# Out:
# Index(['MSZoning', 'Street', 'Alley', 'LotShape', 'LandContour', 'Utilities',
#        'LotConfig', 'LandSlope', 'Neighborhood', 'Condition1', 'Condition2',
#        'BldgType', 'HouseStyle', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'MasVnrType', 'ExterQual', 'ExterCond', 'Foundation',
#        'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Heating', 'HeatingQC', 'CentralAir', 'Electrical', 'KitchenQual',
#        'Functional', 'FireplaceQu', 'GarageType', 'GarageFinish', 'GarageQual',
#        'GarageCond', 'PavedDrive', 'PoolQC', 'Fence', 'MiscFeature',
#        'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
percent = (data.isna().sum()/data.isna().count()).sort_values(ascending=False)
percent
# Out:
# PoolQC           0.996574
# MiscFeature      0.964029
# Alley            0.932169
# Fence            0.804385
# FireplaceQu      0.486468
# LotFrontage      0.166495
# GarageCond       0.054471
# GarageQual       0.054471
# GarageYrBlt      0.054471
# GarageFinish     0.054471
# GarageType       0.053786
# BsmtCond         0.028092
# BsmtExposure     0.028092
# BsmtQual         0.027749
# BsmtFinType2     0.027407
# BsmtFinType1     0.027064
# MasVnrType       0.008222
# MasVnrArea       0.007879
# MSZoning         0.001370
# BsmtHalfBath     0.000685
# Utilities        0.000685
# Functional       0.000685
# BsmtFullBath     0.000685
# BsmtFinSF2       0.000343
# BsmtFinSF1       0.000343
# Exterior2nd      0.000343
# BsmtUnfSF        0.000343
# TotalBsmtSF      0.000343
# Exterior1st      0.000343
# SaleType         0.000343
# Electrical       0.000343
# KitchenQual      0.000343
# GarageArea       0.000343
# GarageCars       0.000343
# OverallQual      0.000000
# ...

# %%
percent["GarageCars"]
# Out:
# 0.00034258307639602604

# %%
fillNaStrategy={"MSZoning":"mode","KitchenQual":"mode","Functional":"mode","SaleType":"mode"}

fillNaValue={"LotFrontage":0,"Alley":"NA","MasVnrType":"None","MasVnrArea":0,"BsmtQual":"NA","BsmtCond":"NA","BsmtExposure":"NA",
"BsmtFinType1":"NA","BsmtFinSF1":0,"BsmtFinType2":"NA","BsmtFinSF2":0,"BsmtFullBath":0,"BsmtHalfBath":0,"FireplaceQu":"NA","GarageType":"NA","GarageFinish":"NA","GarageCars":0,
"GarageArea":0,"GarageQual":"NA","GarageCond":"NA","PoolQC":"NA","Fence":"NA","MiscFeature":"NA"}

knnCols={"Utilities":["MSSubClass","MSZoning","Neighborhood","YearBuilt","YearRemodAdd"],"Exterior1st":["MSSubClass","MSZoning","YearBuilt"],"Exterior2nd":["MSSubClass","MSZoning","YearBuilt"],
"Electrical":["MSSubClass","MSZoning","Neighborhood","YearBuilt","YearRemodAdd"]}

dropNaCols=["TotalBsmtSF","BsmtUnfSF","GarageYrBlt"]

categoryCols=["MSSubClass"]

numCols={"ExterQual":{"Ex":4,"Gd":3,"TA":2,"Fa":1,"Po":0},"ExterCond":{"Ex":4,"Gd":3,"TA":2,"Fa":1,"Po":0},"BsmtQual":{"Ex":5,"Gd":4,"TA":3,"Fa":2,"Po":1,"NA":0},
"BsmtCond":{"Ex":5,"Gd":4,"TA":3,"Fa":2,"Po":1,"NA":0},"BsmtExposure":{"Gd":3,"Av":2,"Mn":1,"No":0,"NA":0},"BsmtFinType1":{"GLQ":6,"ALQ":5,"BLQ":4,"Rec":3,"LwQ":2,"Unf":1,"NA":0},
"BsmtFinType2":{"GLQ":6,"ALQ":5,"BLQ":4,"Rec":3,"LwQ":2,"Unf":1,"NA":0},"HeatingQC":{"Ex":4,"Gd":3,"TA":2,"Fa":1,"Po":0},"FireplaceQu":{"Ex":5,"Gd":4,"TA":3,"Fa":2,"Po":1,"NA":0},
"GarageFinish":{"Fin":3,"RFn":2,"Unf":1,"NA":0},"GarageQual":{"Ex":5,"Gd":4,"TA":3,"Fa":2,"Po":1,"NA":0},"GarageCond":{"Ex":5,"Gd":4,"TA":3,"Fa":2,"Po":1,"NA":0},
"PoolQC":{"Ex":4,"Gd":3,"TA":2,"Fa":1,"NA":0},"KitchenQual":{"Ex":4,"Gd":3,"TA":2,"Fa":1,"Po":0}}
# Out:
# '\nnumCols={"ExterQual":{"Ex":4,"Gd":3,"TA":2,"Fa":1,"Po":0},"ExterCond":{"Ex":4,"Gd":3,"TA":2,"Fa":1,"Po":0},"BsmtQual":{"Ex":5,"Gd":4,"TA":3,"Fa":2,"Po":1,"NA":0},\n"BsmtCond":{"Ex":5,"Gd":4,"TA":3,"Fa":2,"Po":1,"NA":0},"BsmtExposure":{"Gd":3,"Av":2,"Mn":1,"No":0,"NA":0},"BsmtFinType1":{"GLQ":6,"ALQ":5,"BLQ":4,"Rec":3,"LwQ":2,"Unf":1,"NA":0},\n"BsmtFinType2":{"GLQ":6,"ALQ":5,"BLQ":4,"Rec":3,"LwQ":2,"Unf":1,"NA":0},"HeatingQC":{"Ex":4,"Gd":3,"TA":2,"Fa":1,"Po":0},"FireplaceQu":{"Ex":5,"Gd":4,"TA":3,"Fa":2,"Po":1,"NA":0},\n"GarageFinish":{"Fin":3,"RFn":2,"Unf":1,"NA":0},"GarageQual":{"Ex":5,"Gd":4,"TA":3,"Fa":2,"Po":1,"NA":0},"GarageCond":{"Ex":5,"Gd":4,"TA":3,"Fa":2,"Po":1,"NA":0},\n"PoolQC":{"Ex":4,"Gd":3,"TA":2,"Fa":1,"NA":0},"KitchenQual":{"Ex":4,"Gd":3,"TA":2,"Fa":1,"Po":0}}\n'

# %%
from processors import naColFilter

p1=naColFilter(data,parameters={"cols":dropNaCols,"threshold":0.0})
data=p1.transform(data)
# Out:
# GarageYrBlt    0.054471
# BsmtUnfSF      0.000343
# TotalBsmtSF    0.000343
# dtype: float64
# Drop 3 cols since they high rate of nan values:  Index(['GarageYrBlt', 'BsmtUnfSF', 'TotalBsmtSF'], dtype='object')

# %%
from processors import fillNa

p2=fillNa(data,parameters={"strategy":fillNaStrategy,"values":fillNaValue,"knn cols":knnCols})
data=p2.transform(data)
# Out:
# Try to fill nan values.
# Fill 4 nans in col MSZoning with mode RL
# Fill 486 nans in col LotFrontage with 0
# Fill 2721 nans in col Alley with NA
# Fill 24 nans in col MasVnrType with None
# Fill 23 nans in col MasVnrArea with 0
# Fill 81 nans in col BsmtQual with NA
# Fill 82 nans in col BsmtCond with NA
# Fill 82 nans in col BsmtExposure with NA
# Fill 79 nans in col BsmtFinType1 with NA
# Fill 1 nans in col BsmtFinSF1 with 0
# Fill 80 nans in col BsmtFinType2 with NA
# Fill 1 nans in col BsmtFinSF2 with 0
# Fill 2 nans in col BsmtFullBath with 0
# Fill 2 nans in col BsmtHalfBath with 0
# Fill 1 nans in col KitchenQual with mode TA
# Fill 2 nans in col Functional with mode Typ
# Fill 1420 nans in col FireplaceQu with NA
# Fill 157 nans in col GarageType with NA
# Fill 159 nans in col GarageFinish with NA
# Fill 1 nans in col GarageCars with 0
# Fill 1 nans in col GarageArea with 0
# Fill 159 nans in col GarageQual with NA
# Fill 159 nans in col GarageCond with NA
# ...

# %%
def func(train_test):
    train_test["SqFtPerRoom"] = train_test["GrLivArea"] / (train_test["TotRmsAbvGrd"] +
                                                       train_test["FullBath"] +
                                                       train_test["HalfBath"] +
                                                       train_test["KitchenAbvGr"])

    train_test['Total_Home_Quality'] = train_test['OverallQual'] + train_test['OverallCond']

    train_test['Total_Bathrooms'] = (train_test['FullBath'] + (0.5 * train_test['HalfBath']) +
                                train_test['BsmtFullBath'] + (0.5 * train_test['BsmtHalfBath']))

    train_test["HighQualSF"] = train_test["1stFlrSF"] + train_test["2ndFlrSF"]
    return train_test

from processors import custom

p3=custom(data,parameters={"function":func})
data=p3.transform(data)

# %%
from processors import catToNum

p4=catToNum(data,parameters={"orders":numCols})
data=p4.transform(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-10c653168342> in <module>
#       1 from processors import catToNum
#       2
# ----> 3 p4=catToNum(data,parameters={"orders":numCols})
#       4 data=p4.transform(data)
#
# NameError: name 'numCols' is not defined

# %%
from processors import numToCat

p5=numToCat(data,parameters={"cols":categoryCols})
data=p5.transform(data)
# Out:
# MSSubClass has been set to category col.

# %%
from processors import variationSelector,entropySelector,mutInfoSelector,correlationSelector

p6=correlationSelector(data,parameters={"threshold":0.9})
data=p6.transform(data)
# Out:
# Drop 2 cols since they highly related to other cols:  ['KitchenAbvGr', 'BsmtFinSF2']

# %%
from processors import normalization

p9=normalization(data,y)
data,y=p9.transform(data,y)
# Out:
# Try to normalize col:  1stFlrSF
# Skew is -0.0009113724603088824 now.
# Try to normalize col:  GrLivArea
# Skew is -0.0002833781076652133 now.
# Try to normalize col:  SqFtPerRoom
# Skew is -0.007871018926222065 now.
# Try to normalize col:  HighQualSF
# Skew is -2.729090677315011e-05 now.
# Try to normalize label
# Skew is -0.008653727908094083 now.
# /Users/harmonialeo/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:205: RuntimeWarning: overflow encountered in multiply
#   x = um.multiply(x, x, out=x)
# /Users/harmonialeo/opt/anaconda3/lib/python3.8/site-packages/scipy/optimize/optimize.py:2116: RuntimeWarning: invalid value encountered in double_scalars
#   tmp2 = (x - v) * (fx - fw)
# /Users/harmonialeo/opt/anaconda3/lib/python3.8/site-packages/scipy/stats/morestats.py:908: RuntimeWarning: divide by zero encountered in log
#   return (lmb - 1) * np.sum(logdata, axis=0) - N/2 * np.log(variance)
# ...

# %%
from processors import normalizeFilter

X=data.loc[trainIds]
test=data.loc[testIds]
p10=normalizeFilter(X,y)
X,y=p10.transform(X,y)
trainIds=X.index
data=X.append(test)
# Out:
# Scanning cols:  ['1stFlrSF', 'GrLivArea', 'SqFtPerRoom', 'HighQualSF']
# The means are:
#  1stFlrSF       5.656018
# GrLivArea      6.946958
# SqFtPerRoom    2.438321
# HighQualSF     7.231288
# dtype: float64
# The standard deviations are:
#  1stFlrSF       0.203419
# GrLivArea      0.304319
# SqFtPerRoom    0.031737
# HighQualSF     0.330554
# dtype: float64
# Try to filter data with normal distribution.
# Dropped rows:  (array([  29,  125,  197,  496,  523,  528,  533,  691,  705,  916, 1100,
#        1182, 1298]),)

# %%
from models import linear,ridge,lasso,elasticNet,SVMRegression,dtRegression,rfRegression,gbRegression,xgbRegression,lgbmRegression,lgbmRegression_goss,catBoostRegression
models=[]
models.append(linear(data.loc[trainIds],y,maxEpoch=0))

# %%
#models.append(dtRegression(data.loc[trainIds],y,maxEpoch=0,parameters={'max_depth': 9, 'max_features': 0.933924637609429, 'min_samples_split': 0.0261123374395733}))

# %%
#models.append(rfRegression(data.loc[trainIds],y,maxEpoch=0,parameters={'max_depth': 36, 'max_features': 0.5338220435959048, 'min_samples_split': 1.05931019e-08, 'num': 376}))

# %%
#models.append(xgbRegression(data.loc[trainIds],y,maxEpoch=10,modelSavePath="checkpoint/xgb",modelSaveFreq=1))

# %%
#xgbRegression(data.loc[trainIds],y,maxEpoch=10,modelLoadPath="/Users/harmonialeo/Documents/source/convergencer/checkpoint/xgb/xgbRegression-model-final").inference(data.loc[testIds])

# %%
models.append(lgbmRegression(data.loc[trainIds],y,maxEpoch=10))

# %%
#lgbmRegression(data.loc[trainIds],y,maxEpoch=10,modelLoadPath="/Users/harmonialeo/Documents/source/convergencer/checkpoint/lgbm/lgbmRegression-model-final").inference(data.loc[testIds])

# %%
#models.append(lgbmRegression_goss(data.loc[trainIds],y,maxEpoch=0,parameters={'early_stopping_round': 0.0819894148584702, 'feature_fraction': 0.5, 'learning_rate': 0.0108409796892002, 'max_bin': 512, 'max_depth': 5, 'num': 5036, 'num_leaves': 56}))

# %%
models.append(catBoostRegression(data.loc[trainIds],y,maxEpoch=0,modelSavePath="checkpoint/catBoost"))
# Out:
# Model: catBoostRegression initialized
# Initial parameters:  {'iterations': 1000, 'learning_rate': 0.3, 'depth': 8, 'max_bin': 256, 'bagging_temperature': 1.0, 'random_strength': 1.0, 'rsm': 1.0, 'l2_leaf_reg': 3.0, 'od_pval': 0.01}
# Initial score on train set: 0.9821205323057202 Initial score on test set: 0.8987261707375561
# Model: catBoostRegression
# Score on train set: 0.9821205323057202 Score on test set: 0.8987261707375561
# Parameters:  {'iterations': 1000, 'learning_rate': 0.3, 'depth': 8, 'max_bin': 256, 'bagging_temperature': 1.0, 'random_strength': 1.0, 'rsm': 1.0, 'l2_leaf_reg': 3.0, 'od_pval': 0.01}

# %%
catBoostRegression(data.loc[trainIds],y,maxEpoch=0,modelLoadPath="/Users/harmonialeo/Documents/source/convergencer/checkpoint/catBoost/catBoostRegression-model-final").inference(data.loc[testIds])
# Out:
# Model: catBoostRegression
# Loaded from: /Users/harmonialeo/Documents/source/convergencer/checkpoint/catBoost/catBoostRegression-model-final
# 0       7.732315
# 1       7.807053
# 2       7.925984
# 3       7.891662
# 4       7.886681
#           ...
# 1454    7.602734
# 1455    7.544761
# 1456    7.820366
# 1457    7.676712
# 1458    7.928375
# Length: 1459, dtype: float64

# %%
#from models import baggingRegression

#bag=baggingRegression(X,y,models=models,maxEpoch=500)

# %%
import pandas as pd

X_stack=pd.DataFrame()
for model in models:
    X_stack[str(model)]=model.inference(data.loc[trainIds])

# %%
stack2=linear(X_stack,y,maxEpoch=50)

# %%
stack2=ridge(X_stack,y,maxEpoch=50)

# %%
stack2=lasso(X_stack,y,maxEpoch=50)

# %%
stack1=elasticNet(X_stack,y,maxEpoch=50)

# %%
stack1=SVMRegression(X_stack,y,maxEpoch=50)

# %%
stack1=dtRegression(X_stack,y,maxEpoch=150)

# %%
stack1=rfRegression(X_stack,y,maxEpoch=150)
